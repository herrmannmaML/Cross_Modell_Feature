# %%
import os
import sys
import warnings
from datasets import DatasetDict

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from src.utils import (count_images_per_split, find_unique_labels, count_labels_per_split,
                       plot_label_counts, display_class_image_examples)

# zeige keine Warnungen an
warnings.filterwarnings("ignore")

# %%
dataset = DatasetDict.load_from_disk("../data/processed_final")

# %%
dataset["train"].features

# %%
# Anzahl der Bilder pro Split zählen
image_counts = count_images_per_split(dataset)
print("Anzahl der Bilder pro Split:", image_counts)
# Out:
# Anzahl der Bilder pro Split: {'train': 2436, 'validation': 523, 'test': 523}

# %%
# Eindeutige Labels finden
unique_labels = find_unique_labels(dataset)
print("Eindeutige Labels:", unique_labels)
# Out:
# Eindeutige Labels: ['Form', 'News', 'Report', 'Letter', 'Resume', 'ADVE', 'Email', 'Memo', 'Note', 'Scientific']

# %% [markdown]
# ### Anzahl der Bilder je Klasse

# %%
# Anzahl der Labels pro Split zählen
label_counts = count_labels_per_split(dataset)
print("Anzahl der Labels pro Split:", label_counts)
# Out:
# Anzahl der Labels pro Split: {'train': {'Form': 301, 'News': 132, 'Report': 185, 'Letter': 397, 'Resume': 84, 'ADVE': 160, 'Email': 419, 'Memo': 434, 'Note': 141, 'Scientific': 183}, 'validation': {'Form': 65, 'News': 28, 'Report': 40, 'Memo': 93, 'Letter': 85, 'Resume': 18, 'ADVE': 35, 'Scientific': 39, 'Email': 90, 'Note': 30}, 'test': {'Form': 65, 'News': 28, 'Report': 40, 'Letter': 85, 'Resume': 18, 'ADVE': 35, 'Email': 90, 'Memo': 93, 'Note': 30, 'Scientific': 39}}

# %%
plot_label_counts(label_counts)

# %% [markdown]
# ### Beispieldokumente je Klasse

# %%
display_class_image_examples(dataset["train"], 3)
